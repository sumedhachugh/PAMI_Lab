# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
fruit_classify = pd.read_csv("/Users/sumedha/Desktop/PM01.csv")
#fruit_classify.head()
sns.lineplot(data=fruit_classify)

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
iris_data1 = pd.read_csv("/Users/sumedha/Desktop/Setosa.csv")
iris_data2 = pd.read_csv("/Users/sumedha/Desktop/Versicolor.csv")
iris_data3 = pd.read_csv("/Users/sumedha/Desktop/Virginia.csv")
sns.lineplot(data=iris_data1)
sns.lineplot(data=iris_data2)
sns.lineplot(data=iris_data3)

# %%
iris_data = pd.read_csv("/Users/sumedha/Desktop/iris.csv")
sns.scatterplot(x=iris_data['Id'], y=iris_data['SepalLengthCm'], hue = iris_data['Species'])

# %%
iris_data = pd.read_csv("/Users/sumedha/Desktop/iris.csv")
sns.scatterplot(x=iris_data['Id'], y=iris_data['SepalWidthCm'], hue = iris_data['Species'])

# %%
iris_data = pd.read_csv("/Users/sumedha/Desktop/iris.csv")
sns.scatterplot(x=iris_data['Id'], y=iris_data['PetalLengthCm'], hue = iris_data['Species'])

# %%
iris_data = pd.read_csv("/Users/sumedha/Desktop/iris.csv")
sns.scatterplot(x=iris_data['Id'], y=iris_data['PetalWidthCm'], hue = iris_data['Species'])

# %%
#plt.figure(figsize=(8,16))
iris_data134 = pd.read_csv("/Users/sumedha/Desktop/iris134.csv")
sns.lineplot(data=iris_data134)
#plt.figure(figsize=(1,0.5))
